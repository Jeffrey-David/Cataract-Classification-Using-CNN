# %% [markdown]
# <h1><font size="6">Cataract Classification</font></h1>
#
# In this notebook, uses two retina datasets to challenge the cataract classification.
#
# ## Contents
# * [Import libraries](#import)
# * [Set configurations and read metadata](#set)
# * [Process Cataract dataset](#process1)
# * [Process Ocular disease recognition dataset](#process2)
# * [Create datasets](#create)
# * [Build the model(1)](#build1)
# * [Build the model(2)](#build2)

# %% [markdown]
# ## Import libraries <a name="import"> </a>

# %%
# !pip install -q efficientnet >> /dev/null
# Out:
# WARNING: You are using pip version 20.2.1; however, version 20.2.2 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
import os, glob, cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import get_custom_objects
import efficientnet.tfkeras as efn
from tqdm import tqdm

# %% [markdown]
# ## Set configurations and read metadata <a name="set"> </a>

# %%
SEED = 42
EPOCHS = 100
BATCH_SIZE = 32
IMG_HEIGHT = 192
IMG_WIDTH = 256

# cataract dataset
IMG_ROOT = '../input/cataractdataset/dataset/'
IMG_DIR = [IMG_ROOT+'1_normal', 
           IMG_ROOT+'2_cataract', 
           IMG_ROOT+'2_glaucoma', 
           IMG_ROOT+'3_retina_disease']

# ocular-disease-recognition dataset
OCU_IMG_ROOT = '../input/ocular-disease-recognition-odir5k/ODIR-5K/Training Images/'
ocu_df = pd.read_excel('../input/ocular-disease-recognition-odir5k/ODIR-5K/data.xlsx')

# %%
def seed_everything(seed):
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)

seed_everything(SEED)

# %% [markdown]
# ## Process Cataract dataset <a name="process1"> </a>

# %%
cat_df = pd.DataFrame(0, 
                  columns=['paths', 
                           'cataract'],
                  index=range(601))

filepaths = glob.glob(IMG_ROOT + '*/*')


for i, filepath in enumerate(filepaths):
    filepath = os.path.split(filepath)
    cat_df.iloc[i, 0] = filepath[0] + '/' + filepath[1]
    
    if filepath[0] == IMG_DIR[0]:    # normal
        cat_df.iloc[i, 1] = 0
    elif filepath[0] == IMG_DIR[1]:  # cataract
        cat_df.iloc[i, 1] = 1
    elif filepath[0] == IMG_DIR[2]:  # glaucoma
        cat_df.iloc[i, 1] = 2
    elif filepath[0] == IMG_DIR[3]:  # retine_disease
        cat_df.iloc[i, 1] = 3
        
# only sample normal and cataract        
cat_df = cat_df.query('0 <= cataract < 2')
cat_df
# Out:
#                                                  paths  cataract
# 100  ../input/cataractdataset/dataset/1_normal/NL_2...         0
# 101  ../input/cataractdataset/dataset/1_normal/NL_2...         0
# 102  ../input/cataractdataset/dataset/1_normal/NL_0...         0
# 103  ../input/cataractdataset/dataset/1_normal/NL_1...         0
# 104  ../input/cataractdataset/dataset/1_normal/NL_1...         0
# ..                                                 ...       ...
# 495  ../input/cataractdataset/dataset/2_cataract/ca...         1
# 496  ../input/cataractdataset/dataset/2_cataract/ca...         1
# 497  ../input/cataractdataset/dataset/2_cataract/ca...         1
# 498  ../input/cataractdataset/dataset/2_cataract/ca...         1
# 499  ../input/cataractdataset/dataset/2_cataract/ca...         1
#
# [400 rows x 2 columns]

# %%
print('Number of normal and cataract images')
print(cat_df['cataract'].value_counts())
# Out:
# Number of normal and cataract images
# 0    300
# 1    100
# Name: cataract, dtype: int64

# %% [markdown]
# ## Process Ocular disease recognition dataset <a name="process2"> </a>

# %%
ocu_df.head()
# Out:
#    ID  Patient Age Patient Sex Left-Fundus Right-Fundus  \
# 0   0           69      Female  0_left.jpg  0_right.jpg
# 1   1           57        Male  1_left.jpg  1_right.jpg
# 2   2           42        Male  2_left.jpg  2_right.jpg
# 3   3           66        Male  3_left.jpg  3_right.jpg
# 4   4           53        Male  4_left.jpg  4_right.jpg
#
#                             Left-Diagnostic Keywords  \
# 0                                           cataract
# 1                                      normal fundus
# 2  laser spot，moderate non proliferative retinopathy
# 3                                      normal fundus
# 4                        macular epiretinal membrane
#
#                 Right-Diagnostic Keywords  N  D  G  C  A  H  M  O
# 0                           normal fundus  0  0  0  1  0  0  0  0
# 1                           normal fundus  1  0  0  0  0  0  0  0
# 2  moderate non proliferative retinopathy  0  1  0  0  0  0  0  1
# 3         branch retinal artery occlusion  0  0  0  0  0  0  0  1
# 4       mild nonproliferative retinopathy  0  1  0  0  0  0  0  1

# %%
def has_cataract_mentioned(text):
    if 'cataract' in text:
        return 1
    else:
        return 0
    
ocu_df['left_eye_cataract'] = ocu_df['Left-Diagnostic Keywords']\
                                 .apply(lambda x: has_cataract_mentioned(x))
ocu_df['right_eye_cataract'] = ocu_df['Right-Diagnostic Keywords']\
                                 .apply(lambda x: has_cataract_mentioned(x))

# %%
le_df = ocu_df.loc[:, ['Left-Fundus', 'left_eye_cataract']]\
        .rename(columns={'left_eye_cataract':'cataract'})
le_df['paths'] = OCU_IMG_ROOT + le_df['Left-Fundus']
le_df = le_df.drop('Left-Fundus', axis=1)


re_df = ocu_df.loc[:, ['Right-Fundus', 'right_eye_cataract']]\
        .rename(columns={'right_eye_cataract':'cataract'})
re_df['paths'] = OCU_IMG_ROOT + re_df['Right-Fundus']
re_df = re_df.drop('Right-Fundus', axis=1)

# %%
le_df.head()
# Out:
#    cataract                                              paths
# 0         1  ../input/ocular-disease-recognition-odir5k/ODI...
# 1         0  ../input/ocular-disease-recognition-odir5k/ODI...
# 2         0  ../input/ocular-disease-recognition-odir5k/ODI...
# 3         0  ../input/ocular-disease-recognition-odir5k/ODI...
# 4         0  ../input/ocular-disease-recognition-odir5k/ODI...

# %%
re_df.head()
# Out:
#    cataract                                              paths
# 0         0  ../input/ocular-disease-recognition-odir5k/ODI...
# 1         0  ../input/ocular-disease-recognition-odir5k/ODI...
# 2         0  ../input/ocular-disease-recognition-odir5k/ODI...
# 3         0  ../input/ocular-disease-recognition-odir5k/ODI...
# 4         0  ../input/ocular-disease-recognition-odir5k/ODI...

# %%
print('Number of left eye images')
print(le_df['cataract'].value_counts())
print('\nNumber of right eye images')
print(re_df['cataract'].value_counts())
# Out:
# Number of left eye images
# 0    3341
# 1     159
# Name: cataract, dtype: int64
#
# Number of right eye images
# 0    3346
# 1     154
# Name: cataract, dtype: int64

# %% [markdown]
# There is a large bias in the dataset. So make it even.

# %%
def downsample(df):
    df = pd.concat([
        df.query('cataract==1'),
        df.query('cataract==0').sample(sum(df['cataract']), 
                                       random_state=SEED)
    ])
    return df


le_df = downsample(le_df)
re_df = downsample(re_df)

print('Number of left eye images')
print(le_df['cataract'].value_counts())
print('\nNumber of right eye images')
print(re_df['cataract'].value_counts())
# Out:
# Number of left eye images
# 1    159
# 0    159
# Name: cataract, dtype: int64
#
# Number of right eye images
# 1    154
# 0    154
# Name: cataract, dtype: int64

# %%
ocu_df = pd.concat([le_df, re_df])
ocu_df.head()
# Out:
#      cataract                                              paths
# 0           1  ../input/ocular-disease-recognition-odir5k/ODI...
# 81          1  ../input/ocular-disease-recognition-odir5k/ODI...
# 103         1  ../input/ocular-disease-recognition-odir5k/ODI...
# 119         1  ../input/ocular-disease-recognition-odir5k/ODI...
# 253         1  ../input/ocular-disease-recognition-odir5k/ODI...

# %% [markdown]
# ## Create datasets <a name="create"> </a>
# Combine the two metadata and use them to load the image data and create datasets.

# %%
df = pd.concat([cat_df, ocu_df], ignore_index=True)
df
# Out:
#                                                   paths  cataract
# 0     ../input/cataractdataset/dataset/1_normal/NL_2...         0
# 1     ../input/cataractdataset/dataset/1_normal/NL_2...         0
# 2     ../input/cataractdataset/dataset/1_normal/NL_0...         0
# 3     ../input/cataractdataset/dataset/1_normal/NL_1...         0
# 4     ../input/cataractdataset/dataset/1_normal/NL_1...         0
# ...                                                 ...       ...
# 1021  ../input/ocular-disease-recognition-odir5k/ODI...         0
# 1022  ../input/ocular-disease-recognition-odir5k/ODI...         0
# 1023  ../input/ocular-disease-recognition-odir5k/ODI...         0
# 1024  ../input/ocular-disease-recognition-odir5k/ODI...         0
# 1025  ../input/ocular-disease-recognition-odir5k/ODI...         0
#
# [1026 rows x 2 columns]

# %%
train_df, test_df = train_test_split(df, 
                                     test_size=0.2, 
                                     random_state=SEED, 
                                     stratify=df['cataract'])

train_df, val_df = train_test_split(train_df,
                                    test_size=0.15,
                                    random_state=SEED,
                                    stratify=train_df['cataract'])

# %%
def create_datasets(df, img_width, img_height):
    imgs = []
    for path in tqdm(df['paths']):
        img = cv2.imread(path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (img_width, img_height))
        imgs.append(img)
        
    imgs = np.array(imgs, dtype='float32')
    df = pd.get_dummies(df['cataract'])
    return imgs, df


train_imgs, train_df = create_datasets(train_df, IMG_WIDTH, IMG_HEIGHT)
val_imgs, val_df = create_datasets(val_df, IMG_WIDTH, IMG_HEIGHT)
test_imgs, test_df = create_datasets(test_df, IMG_WIDTH, IMG_HEIGHT)

train_imgs = train_imgs / 255.0
val_imgs = val_imgs / 255.0
test_imgs = test_imgs / 255.0
# Out:
# 100%|██████████| 697/697 [00:47<00:00, 14.62it/s]
# 100%|██████████| 123/123 [00:07<00:00, 15.44it/s]
# 100%|██████████| 206/206 [00:14<00:00, 14.22it/s]

# %%
# plot the first 25 sheets of image data for training

f, ax = plt.subplots(5, 5, figsize=(15,15))
norm_list = list(train_df[0][:25])
for i, img in enumerate(train_imgs[:25]):
    ax[i//5, i%5].imshow(img)
    ax[i//5, i%5].axis('off')
    if norm_list[i] == 1:
        ax[i//5, i%5].set_title('TrainData: Normal')
    else:
        ax[i//5, i%5].set_title('TrainData: Cataract')
plt.show()

# %%
# plot the first 25 sheets of image data for Test
f, ax = plt.subplots(5, 5, figsize=(15,15))
norm_list = list(test_df[0][:25])
for i, img in enumerate(test_imgs[:25]):
    ax[i//5, i%5].imshow(img)
    ax[i//5, i%5].axis('off')
    if norm_list[i] == 1:
        ax[i//5, i%5].set_title('TestData: Normal')
    else:
        ax[i//5, i%5].set_title('TestData: Cataract')
plt.show()

# %% [markdown]
# ## Build the model(1) <a name="build1"> </a>

# %%
class Mish(tf.keras.layers.Layer):

    def __init__(self, **kwargs):
        super(Mish, self).__init__(**kwargs)
        self.supports_masking = True

    def call(self, inputs):
        return inputs * K.tanh(K.softplus(inputs))

    def get_config(self):
        base_config = super(Mish, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

    def compute_output_shape(self, input_shape):
        return input_shape
def mish(x):
    return tf.keras.layers.Lambda(lambda x: x*K.tanh(K.softplus(x)))(x)
 
get_custom_objects().update({'mish': Activation(mish)})

# %%
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)

model = Sequential()
model.add(Conv2D(16, kernel_size=3, padding='same', 
                 input_shape=input_shape, activation='mish'))
model.add(Conv2D(16, kernel_size=3, padding='same', activation='mish'))
model.add(BatchNormalization())
model.add(MaxPool2D(3))
model.add(Dropout(0.3))
model.add(Conv2D(16, kernel_size=3, padding='same', activation='mish'))
model.add(Conv2D(16, kernel_size=3, padding='same', activation='mish'))
model.add(BatchNormalization())
model.add(MaxPool2D(3))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(2, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 192, 256, 16)      448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 192, 256, 16)      2320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 192, 256, 16)      64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 85, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 85, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 85, 16)        2320
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 85, 16)        2320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 85, 16)        64
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 21, 28, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 21, 28, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 9408)              0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 18818
# =================================================================
# Total params: 26,354
# Trainable params: 26,290
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# Use some image data augmentation to generate randomly augmented image data from the ImageDataGenerator Object.

# %%
generator = ImageDataGenerator(horizontal_flip=True, 
                               height_shift_range=0.1,
                               fill_mode='reflect') 



es_callback = tf.keras.callbacks.EarlyStopping(patience=20, 
                                               verbose=1, 
                                               restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=10, verbose=1)

# %%
history = model.fit(generator.flow(train_imgs, 
                                   train_df,
                                   batch_size=BATCH_SIZE), 
                    epochs=EPOCHS,
                    steps_per_epoch=len(train_imgs)/BATCH_SIZE,
                    callbacks=[es_callback, reduce_lr],
                    validation_data=(val_imgs, val_df))


pd.DataFrame(history.history)[['accuracy', 'val_accuracy']].plot()
pd.DataFrame(history.history)[['loss', 'val_loss']].plot()
plt.show()
# Out:
# Epoch 1/100
# 22/21 [==============================] - 8s 372ms/step - loss: 1.6089 - accuracy: 0.6055 - val_loss: 0.6424 - val_accuracy: 0.6423
# Epoch 2/100
# 22/21 [==============================] - 7s 332ms/step - loss: 0.9707 - accuracy: 0.6944 - val_loss: 0.6512 - val_accuracy: 0.6260
# Epoch 3/100
# 22/21 [==============================] - 7s 328ms/step - loss: 0.8525 - accuracy: 0.7016 - val_loss: 0.7368 - val_accuracy: 0.3984
# Epoch 4/100
# 22/21 [==============================] - 7s 309ms/step - loss: 1.0418 - accuracy: 0.6772 - val_loss: 0.6861 - val_accuracy: 0.4065
# Epoch 5/100
# 22/21 [==============================] - 7s 321ms/step - loss: 0.7170 - accuracy: 0.7389 - val_loss: 0.6293 - val_accuracy: 0.6016
# Epoch 6/100
# 22/21 [==============================] - 7s 300ms/step - loss: 0.6972 - accuracy: 0.7475 - val_loss: 0.6699 - val_accuracy: 0.4878
# Epoch 7/100
# 22/21 [==============================] - 7s 326ms/step - loss: 0.8368 - accuracy: 0.7346 - val_loss: 0.6238 - val_accuracy: 0.6098
# Epoch 8/100
# 22/21 [==============================] - 7s 313ms/step - loss: 0.9030 - accuracy: 0.7317 - val_loss: 0.5814 - val_accuracy: 0.7073
# Epoch 9/100
# 22/21 [==============================] - 7s 322ms/step - loss: 0.6494 - accuracy: 0.7633 - val_loss: 0.6152 - val_accuracy: 0.7805
# Epoch 10/100
# 22/21 [==============================] - 7s 336ms/step - loss: 0.6289 - accuracy: 0.7905 - val_loss: 0.7666 - val_accuracy: 0.4146
# Epoch 11/100
# 22/21 [==============================] - 7s 312ms/step - loss: 0.7485 - accuracy: 0.7489 - val_loss: 0.7941 - val_accuracy: 0.4228
# Epoch 12/100
# 22/21 [==============================] - 7s 323ms/step - loss: 0.7525 - accuracy: 0.7475 - val_loss: 0.5073 - val_accuracy: 0.7398
# Epoch 13/100
# 22/21 [==============================] - 7s 302ms/step - loss: 0.6271 - accuracy: 0.7862 - val_loss: 0.5252 - val_accuracy: 0.7480
# Epoch 14/100
# 22/21 [==============================] - 7s 323ms/step - loss: 0.6291 - accuracy: 0.7733 - val_loss: 0.5388 - val_accuracy: 0.6992
# Epoch 15/100
# 22/21 [==============================] - 7s 298ms/step - loss: 0.6428 - accuracy: 0.7747 - val_loss: 0.4603 - val_accuracy: 0.7317
# Epoch 16/100
# 22/21 [==============================] - 7s 317ms/step - loss: 0.6919 - accuracy: 0.7719 - val_loss: 0.4545 - val_accuracy: 0.8211
# Epoch 17/100
# 22/21 [==============================] - 8s 348ms/step - loss: 0.6102 - accuracy: 0.7676 - val_loss: 0.7871 - val_accuracy: 0.6341
# Epoch 18/100
# 22/21 [==============================] - 7s 331ms/step - loss: 0.5680 - accuracy: 0.7791 - val_loss: 0.5354 - val_accuracy: 0.7154
# Epoch 19/100
# 22/21 [==============================] - 6s 294ms/step - loss: 0.6298 - accuracy: 0.7819 - val_loss: 0.5987 - val_accuracy: 0.6423
# Epoch 20/100
# 22/21 [==============================] - 7s 327ms/step - loss: 0.7750 - accuracy: 0.7532 - val_loss: 0.4618 - val_accuracy: 0.7805
# Epoch 21/100
# 22/21 [==============================] - 7s 317ms/step - loss: 0.7872 - accuracy: 0.7489 - val_loss: 1.0179 - val_accuracy: 0.6748
# Epoch 22/100
# 22/21 [==============================] - 7s 301ms/step - loss: 0.6174 - accuracy: 0.7791 - val_loss: 0.8345 - val_accuracy: 0.7561
# Epoch 23/100
# 22/21 [==============================] - 7s 315ms/step - loss: 0.5235 - accuracy: 0.8049 - val_loss: 0.4960 - val_accuracy: 0.8211
# Epoch 24/100
# 22/21 [==============================] - 7s 308ms/step - loss: 0.5635 - accuracy: 0.8034 - val_loss: 0.5589 - val_accuracy: 0.7724
# Epoch 25/100
# 22/21 [==============================] - 7s 328ms/step - loss: 0.8850 - accuracy: 0.7618 - val_loss: 0.4435 - val_accuracy: 0.8130
# Epoch 26/100
# 22/21 [==============================] - 7s 340ms/step - loss: 0.6136 - accuracy: 0.7805 - val_loss: 0.4228 - val_accuracy: 0.8293
# Epoch 27/100
# 22/21 [==============================] - 7s 319ms/step - loss: 0.4974 - accuracy: 0.8307 - val_loss: 0.8626 - val_accuracy: 0.7561
# Epoch 28/100
# 22/21 [==============================] - 7s 301ms/step - loss: 0.5017 - accuracy: 0.8092 - val_loss: 0.4240 - val_accuracy: 0.8211
# Epoch 29/100
# 22/21 [==============================] - 7s 329ms/step - loss: 0.4531 - accuracy: 0.8207 - val_loss: 0.3318 - val_accuracy: 0.8699
# Epoch 30/100
# 22/21 [==============================] - 7s 316ms/step - loss: 0.3709 - accuracy: 0.8522 - val_loss: 0.6164 - val_accuracy: 0.8293
# Epoch 31/100
# 22/21 [==============================] - 7s 301ms/step - loss: 0.4925 - accuracy: 0.8350 - val_loss: 0.5897 - val_accuracy: 0.8293
# Epoch 32/100
# 22/21 [==============================] - 7s 311ms/step - loss: 0.4308 - accuracy: 0.8508 - val_loss: 0.5311 - val_accuracy: 0.8130
# Epoch 33/100
# 22/21 [==============================] - 8s 351ms/step - loss: 0.4777 - accuracy: 0.8350 - val_loss: 0.7865 - val_accuracy: 0.7805
# Epoch 34/100
# 22/21 [==============================] - 7s 336ms/step - loss: 0.5573 - accuracy: 0.8164 - val_loss: 0.3625 - val_accuracy: 0.8780
# Epoch 35/100
# 22/21 [==============================] - 7s 318ms/step - loss: 0.5819 - accuracy: 0.8049 - val_loss: 0.8593 - val_accuracy: 0.6667
# Epoch 36/100
# 22/21 [==============================] - 7s 331ms/step - loss: 0.6071 - accuracy: 0.7991 - val_loss: 0.3565 - val_accuracy: 0.8537
# Epoch 37/100
# 22/21 [==============================] - 7s 311ms/step - loss: 0.5243 - accuracy: 0.8364 - val_loss: 0.8463 - val_accuracy: 0.7886
# Epoch 38/100
# 22/21 [==============================] - 7s 312ms/step - loss: 0.3719 - accuracy: 0.8608 - val_loss: 0.5655 - val_accuracy: 0.8293
# Epoch 39/100
# 22/21 [==============================] - ETA: 0s - loss: 0.3964 - accuracy: 0.8364
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 22/21 [==============================] - 7s 311ms/step - loss: 0.3964 - accuracy: 0.8364 - val_loss: 0.7277 - val_accuracy: 0.7805
# Epoch 40/100
# 22/21 [==============================] - 7s 303ms/step - loss: 0.3411 - accuracy: 0.8709 - val_loss: 0.3707 - val_accuracy: 0.8780
# Epoch 41/100
# 22/21 [==============================] - 8s 349ms/step - loss: 0.2972 - accuracy: 0.8752 - val_loss: 0.3082 - val_accuracy: 0.8862
# Epoch 42/100
# 22/21 [==============================] - 8s 352ms/step - loss: 0.2912 - accuracy: 0.8881 - val_loss: 0.3040 - val_accuracy: 0.8862
# Epoch 43/100
# 22/21 [==============================] - 7s 304ms/step - loss: 0.3097 - accuracy: 0.8780 - val_loss: 0.3105 - val_accuracy: 0.8862
# Epoch 44/100
# 22/21 [==============================] - 7s 316ms/step - loss: 0.3196 - accuracy: 0.8565 - val_loss: 0.3900 - val_accuracy: 0.8862
# Epoch 45/100
# 22/21 [==============================] - 7s 314ms/step - loss: 0.2768 - accuracy: 0.8895 - val_loss: 0.2916 - val_accuracy: 0.8943
# Epoch 46/100
# 22/21 [==============================] - 7s 312ms/step - loss: 0.2887 - accuracy: 0.8910 - val_loss: 0.3144 - val_accuracy: 0.8943
# Epoch 47/100
# 22/21 [==============================] - 7s 312ms/step - loss: 0.3243 - accuracy: 0.8694 - val_loss: 0.3347 - val_accuracy: 0.9106
# Epoch 48/100
# 22/21 [==============================] - 7s 307ms/step - loss: 0.2749 - accuracy: 0.8938 - val_loss: 0.3152 - val_accuracy: 0.8780
# Epoch 49/100
# 22/21 [==============================] - 6s 295ms/step - loss: 0.3038 - accuracy: 0.8881 - val_loss: 0.3244 - val_accuracy: 0.8780
# Epoch 50/100
# 22/21 [==============================] - 8s 361ms/step - loss: 0.2668 - accuracy: 0.8895 - val_loss: 0.3208 - val_accuracy: 0.8943
# Epoch 51/100
# 22/21 [==============================] - 7s 312ms/step - loss: 0.2968 - accuracy: 0.8838 - val_loss: 0.3214 - val_accuracy: 0.8943
# Epoch 52/100
# 22/21 [==============================] - 7s 305ms/step - loss: 0.2586 - accuracy: 0.8924 - val_loss: 0.3117 - val_accuracy: 0.8699
# Epoch 53/100
# 22/21 [==============================] - 7s 323ms/step - loss: 0.2663 - accuracy: 0.8867 - val_loss: 0.3150 - val_accuracy: 0.9187
# Epoch 54/100
# 22/21 [==============================] - 7s 323ms/step - loss: 0.2926 - accuracy: 0.8838 - val_loss: 0.3037 - val_accuracy: 0.8943
# Epoch 55/100
# 22/21 [==============================] - ETA: 0s - loss: 0.2750 - accuracy: 0.8938
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 22/21 [==============================] - 7s 306ms/step - loss: 0.2750 - accuracy: 0.8938 - val_loss: 0.3340 - val_accuracy: 0.8618
# Epoch 56/100
# 22/21 [==============================] - 7s 316ms/step - loss: 0.2951 - accuracy: 0.8895 - val_loss: 0.2950 - val_accuracy: 0.8780
# Epoch 57/100
# 22/21 [==============================] - 7s 320ms/step - loss: 0.3017 - accuracy: 0.8867 - val_loss: 0.2860 - val_accuracy: 0.9024
# Epoch 58/100
# 22/21 [==============================] - 7s 336ms/step - loss: 0.2475 - accuracy: 0.8981 - val_loss: 0.2857 - val_accuracy: 0.9024
# Epoch 59/100
# 22/21 [==============================] - 7s 326ms/step - loss: 0.2584 - accuracy: 0.8953 - val_loss: 0.2856 - val_accuracy: 0.8862
# Epoch 60/100
# 22/21 [==============================] - 7s 310ms/step - loss: 0.2868 - accuracy: 0.8809 - val_loss: 0.2878 - val_accuracy: 0.8780
# Epoch 61/100
# 22/21 [==============================] - 7s 308ms/step - loss: 0.2432 - accuracy: 0.8967 - val_loss: 0.2866 - val_accuracy: 0.9024
# Epoch 62/100
# 22/21 [==============================] - 7s 311ms/step - loss: 0.2811 - accuracy: 0.8867 - val_loss: 0.2866 - val_accuracy: 0.8943
# Epoch 63/100
# 22/21 [==============================] - 7s 324ms/step - loss: 0.2397 - accuracy: 0.8953 - val_loss: 0.2890 - val_accuracy: 0.8943
# Epoch 64/100
# 22/21 [==============================] - 6s 292ms/step - loss: 0.2730 - accuracy: 0.8809 - val_loss: 0.2903 - val_accuracy: 0.8943
# Epoch 65/100
# 22/21 [==============================] - 7s 317ms/step - loss: 0.2770 - accuracy: 0.8838 - val_loss: 0.2925 - val_accuracy: 0.8862
# Epoch 66/100
# 22/21 [==============================] - 8s 345ms/step - loss: 0.2962 - accuracy: 0.8752 - val_loss: 0.2929 - val_accuracy: 0.8943
# Epoch 67/100
# 22/21 [==============================] - 7s 328ms/step - loss: 0.2708 - accuracy: 0.8953 - val_loss: 0.2949 - val_accuracy: 0.8943
# Epoch 68/100
# 22/21 [==============================] - 7s 302ms/step - loss: 0.2722 - accuracy: 0.8910 - val_loss: 0.3032 - val_accuracy: 0.8943
# Epoch 69/100
# 22/21 [==============================] - ETA: 0s - loss: 0.2703 - accuracy: 0.8938
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 22/21 [==============================] - 7s 319ms/step - loss: 0.2703 - accuracy: 0.8938 - val_loss: 0.3000 - val_accuracy: 0.8943
# Epoch 70/100
# 22/21 [==============================] - 7s 295ms/step - loss: 0.2859 - accuracy: 0.8852 - val_loss: 0.3003 - val_accuracy: 0.8943
# Epoch 71/100
# 22/21 [==============================] - 7s 317ms/step - loss: 0.2397 - accuracy: 0.9039 - val_loss: 0.3003 - val_accuracy: 0.8943
# Epoch 72/100
# 22/21 [==============================] - 7s 331ms/step - loss: 0.2626 - accuracy: 0.8981 - val_loss: 0.3006 - val_accuracy: 0.8943
# Epoch 73/100
# 22/21 [==============================] - 7s 296ms/step - loss: 0.2383 - accuracy: 0.9067 - val_loss: 0.3010 - val_accuracy: 0.8943
# Epoch 74/100
# 22/21 [==============================] - 8s 359ms/step - loss: 0.2447 - accuracy: 0.8938 - val_loss: 0.3014 - val_accuracy: 0.8943
# Epoch 75/100
# 22/21 [==============================] - 7s 324ms/step - loss: 0.2884 - accuracy: 0.8680 - val_loss: 0.3016 - val_accuracy: 0.8943
# Epoch 76/100
# 22/21 [==============================] - 7s 331ms/step - loss: 0.2665 - accuracy: 0.8953 - val_loss: 0.3016 - val_accuracy: 0.8943
# Epoch 77/100
# 22/21 [==============================] - 7s 301ms/step - loss: 0.2683 - accuracy: 0.8852 - val_loss: 0.3016 - val_accuracy: 0.8943
# Epoch 78/100
# 22/21 [==============================] - 7s 319ms/step - loss: 0.2637 - accuracy: 0.8867 - val_loss: 0.3021 - val_accuracy: 0.8943
# Epoch 79/100
# 22/21 [==============================] - ETA: 0s - loss: 0.2631 - accuracy: 0.8924Restoring model weights from the end of the best epoch.
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 22/21 [==============================] - 7s 308ms/step - loss: 0.2631 - accuracy: 0.8924 - val_loss: 0.3021 - val_accuracy: 0.8943
# Epoch 00079: early stopping

# %%
model.evaluate(test_imgs, test_df)
# Out:
# 7/7 [==============================] - 0s 19ms/step - loss: 0.3669 - accuracy: 0.8835
# [0.36693450808525085, 0.8834951519966125]

# %% [markdown]
# ## Build the model(2) <a name="build2"> </a>
# We will train using a model that has been pre-trained.

# %%
def build_model(img_height, img_width, n):
    inp = Input(shape=(img_height,img_width,n))
    efnet = efn.EfficientNetB0(
        input_shape=(img_height,img_width,n), 
        weights='imagenet', 
        include_top=False
    )
    x = efnet(inp)
    x = GlobalAveragePooling2D()(x)
    x = Dense(2, activation='softmax')(x)
    model = tf.keras.Model(inputs=inp, outputs=x)
    opt = tf.keras.optimizers.Adam(learning_rate=0.000003)
    loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.01)
    model.compile(optimizer=opt, loss=loss, metrics=['accuracy'])
    return model

model = build_model(IMG_HEIGHT, IMG_WIDTH, 3)
model.summary()
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b0_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 16809984/16804768 [==============================] - 2s 0us/step
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 192, 256, 3)]     0
# _________________________________________________________________
# efficientnet-b0 (Functional) (None, 6, 8, 1280)        4049564
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 2562
# =================================================================
# Total params: 4,052,126
# Trainable params: 4,010,110
# Non-trainable params: 42,016
# _________________________________________________________________

# %%
generator = ImageDataGenerator(horizontal_flip=True, 
                               height_shift_range=0.1,
                               fill_mode='reflect') 



es_callback = tf.keras.callbacks.EarlyStopping(patience=20, 
                                               verbose=1, 
                                               restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=10, verbose=1)

# %%
history = model.fit(generator.flow(train_imgs, 
                                   train_df,
                                   batch_size=BATCH_SIZE), 
                    epochs=EPOCHS,
                    steps_per_epoch=len(train_imgs)/BATCH_SIZE,
                    callbacks=[es_callback, reduce_lr],
                    validation_data=(val_imgs, val_df))


pd.DataFrame(history.history)[['accuracy', 'val_accuracy']].plot()
pd.DataFrame(history.history)[['loss', 'val_loss']].plot()
plt.show()
# Out:
# Epoch 1/100
# 22/21 [==============================] - 11s 499ms/step - loss: 0.7611 - accuracy: 0.4534 - val_loss: 0.5674 - val_accuracy: 0.7236
# Epoch 2/100
# 22/21 [==============================] - 9s 420ms/step - loss: 0.7020 - accuracy: 0.5438 - val_loss: 0.5681 - val_accuracy: 0.7967
# Epoch 3/100
# 22/21 [==============================] - 9s 399ms/step - loss: 0.6718 - accuracy: 0.5638 - val_loss: 0.5778 - val_accuracy: 0.7561
# Epoch 4/100
# 22/21 [==============================] - 9s 410ms/step - loss: 0.6267 - accuracy: 0.6514 - val_loss: 0.5836 - val_accuracy: 0.7073
# Epoch 5/100
# 22/21 [==============================] - 9s 429ms/step - loss: 0.5904 - accuracy: 0.7231 - val_loss: 0.5856 - val_accuracy: 0.7236
# Epoch 6/100
# 22/21 [==============================] - 9s 420ms/step - loss: 0.5755 - accuracy: 0.7260 - val_loss: 0.5796 - val_accuracy: 0.7154
# Epoch 7/100
# 22/21 [==============================] - 10s 444ms/step - loss: 0.5383 - accuracy: 0.7719 - val_loss: 0.5588 - val_accuracy: 0.7154
# Epoch 8/100
# 22/21 [==============================] - 9s 416ms/step - loss: 0.5109 - accuracy: 0.7977 - val_loss: 0.5370 - val_accuracy: 0.7561
# Epoch 9/100
# 22/21 [==============================] - 9s 413ms/step - loss: 0.5016 - accuracy: 0.8092 - val_loss: 0.5150 - val_accuracy: 0.7805
# Epoch 10/100
# 22/21 [==============================] - 9s 422ms/step - loss: 0.4886 - accuracy: 0.8092 - val_loss: 0.4888 - val_accuracy: 0.7967
# Epoch 11/100
# 22/21 [==============================] - 9s 414ms/step - loss: 0.4691 - accuracy: 0.8307 - val_loss: 0.4625 - val_accuracy: 0.8293
# Epoch 12/100
# 22/21 [==============================] - 9s 430ms/step - loss: 0.4451 - accuracy: 0.8350 - val_loss: 0.4415 - val_accuracy: 0.8699
# Epoch 13/100
# 22/21 [==============================] - 10s 440ms/step - loss: 0.4228 - accuracy: 0.8651 - val_loss: 0.4250 - val_accuracy: 0.9024
# Epoch 14/100
# 22/21 [==============================] - 9s 414ms/step - loss: 0.4321 - accuracy: 0.8623 - val_loss: 0.4089 - val_accuracy: 0.8862
# Epoch 15/100
# 22/21 [==============================] - 10s 438ms/step - loss: 0.4022 - accuracy: 0.8680 - val_loss: 0.3969 - val_accuracy: 0.9024
# Epoch 16/100
# 22/21 [==============================] - 9s 410ms/step - loss: 0.3941 - accuracy: 0.8637 - val_loss: 0.3853 - val_accuracy: 0.9024
# Epoch 17/100
# 22/21 [==============================] - 9s 405ms/step - loss: 0.3860 - accuracy: 0.8838 - val_loss: 0.3745 - val_accuracy: 0.9024
# Epoch 18/100
# 22/21 [==============================] - 9s 411ms/step - loss: 0.3687 - accuracy: 0.8780 - val_loss: 0.3633 - val_accuracy: 0.8862
# Epoch 19/100
# 22/21 [==============================] - 10s 433ms/step - loss: 0.3694 - accuracy: 0.8737 - val_loss: 0.3528 - val_accuracy: 0.8943
# Epoch 20/100
# 22/21 [==============================] - 9s 411ms/step - loss: 0.3522 - accuracy: 0.8824 - val_loss: 0.3413 - val_accuracy: 0.8780
# Epoch 21/100
# 22/21 [==============================] - 9s 424ms/step - loss: 0.3444 - accuracy: 0.8953 - val_loss: 0.3288 - val_accuracy: 0.8862
# Epoch 22/100
# 22/21 [==============================] - 9s 404ms/step - loss: 0.3382 - accuracy: 0.8867 - val_loss: 0.3171 - val_accuracy: 0.9106
# Epoch 23/100
# 22/21 [==============================] - 9s 407ms/step - loss: 0.3283 - accuracy: 0.8996 - val_loss: 0.3063 - val_accuracy: 0.9187
# Epoch 24/100
# 22/21 [==============================] - 9s 411ms/step - loss: 0.3172 - accuracy: 0.8953 - val_loss: 0.2976 - val_accuracy: 0.9187
# Epoch 25/100
# 22/21 [==============================] - 10s 448ms/step - loss: 0.3131 - accuracy: 0.8996 - val_loss: 0.2949 - val_accuracy: 0.9106
# Epoch 26/100
# 22/21 [==============================] - 9s 397ms/step - loss: 0.3118 - accuracy: 0.8953 - val_loss: 0.3088 - val_accuracy: 0.9024
# Epoch 27/100
# 22/21 [==============================] - 9s 392ms/step - loss: 0.3300 - accuracy: 0.8852 - val_loss: 0.2992 - val_accuracy: 0.9024
# Epoch 28/100
# 22/21 [==============================] - 9s 428ms/step - loss: 0.2983 - accuracy: 0.9039 - val_loss: 0.2896 - val_accuracy: 0.9024
# Epoch 29/100
# 22/21 [==============================] - 9s 414ms/step - loss: 0.2917 - accuracy: 0.9053 - val_loss: 0.2966 - val_accuracy: 0.9106
# Epoch 30/100
# 22/21 [==============================] - 9s 407ms/step - loss: 0.2946 - accuracy: 0.9110 - val_loss: 0.2961 - val_accuracy: 0.9106
# Epoch 31/100
# 22/21 [==============================] - 10s 451ms/step - loss: 0.2889 - accuracy: 0.9053 - val_loss: 0.2866 - val_accuracy: 0.9106
# Epoch 32/100
# 22/21 [==============================] - 9s 419ms/step - loss: 0.2718 - accuracy: 0.9197 - val_loss: 0.2907 - val_accuracy: 0.9106
# Epoch 33/100
# 22/21 [==============================] - 9s 403ms/step - loss: 0.2815 - accuracy: 0.9010 - val_loss: 0.2966 - val_accuracy: 0.9024
# Epoch 34/100
# 22/21 [==============================] - 9s 418ms/step - loss: 0.2780 - accuracy: 0.9082 - val_loss: 0.2902 - val_accuracy: 0.9024
# Epoch 35/100
# 22/21 [==============================] - 8s 380ms/step - loss: 0.2715 - accuracy: 0.9053 - val_loss: 0.3027 - val_accuracy: 0.9106
# Epoch 36/100
# 22/21 [==============================] - 9s 388ms/step - loss: 0.2537 - accuracy: 0.9168 - val_loss: 0.2872 - val_accuracy: 0.9024
# Epoch 37/100
# 22/21 [==============================] - 9s 415ms/step - loss: 0.2624 - accuracy: 0.9053 - val_loss: 0.2903 - val_accuracy: 0.9024
# Epoch 38/100
# 22/21 [==============================] - 9s 420ms/step - loss: 0.2682 - accuracy: 0.9110 - val_loss: 0.2899 - val_accuracy: 0.9024
# Epoch 39/100
# 22/21 [==============================] - 9s 396ms/step - loss: 0.2430 - accuracy: 0.9297 - val_loss: 0.2728 - val_accuracy: 0.9106
# Epoch 40/100
# 22/21 [==============================] - 9s 399ms/step - loss: 0.2480 - accuracy: 0.9139 - val_loss: 0.3045 - val_accuracy: 0.9106
# Epoch 41/100
# 22/21 [==============================] - 9s 408ms/step - loss: 0.2472 - accuracy: 0.9182 - val_loss: 0.2704 - val_accuracy: 0.9187
# Epoch 42/100
# 22/21 [==============================] - 8s 380ms/step - loss: 0.2545 - accuracy: 0.9082 - val_loss: 0.2741 - val_accuracy: 0.9024
# Epoch 43/100
# 22/21 [==============================] - 9s 401ms/step - loss: 0.2466 - accuracy: 0.9168 - val_loss: 0.3278 - val_accuracy: 0.9024
# Epoch 44/100
# 22/21 [==============================] - 10s 441ms/step - loss: 0.2535 - accuracy: 0.9211 - val_loss: 0.2866 - val_accuracy: 0.9024
# Epoch 45/100
# 22/21 [==============================] - 9s 396ms/step - loss: 0.2423 - accuracy: 0.9197 - val_loss: 0.2892 - val_accuracy: 0.9024
# Epoch 46/100
# 22/21 [==============================] - 9s 389ms/step - loss: 0.2302 - accuracy: 0.9240 - val_loss: 0.2946 - val_accuracy: 0.9024
# Epoch 47/100
# 22/21 [==============================] - 9s 399ms/step - loss: 0.2443 - accuracy: 0.9211 - val_loss: 0.2833 - val_accuracy: 0.9024
# Epoch 48/100
# 22/21 [==============================] - 9s 395ms/step - loss: 0.2349 - accuracy: 0.9254 - val_loss: 0.2916 - val_accuracy: 0.9024
# Epoch 49/100
# 22/21 [==============================] - 8s 375ms/step - loss: 0.2282 - accuracy: 0.9297 - val_loss: 0.3002 - val_accuracy: 0.9024
# Epoch 50/100
# 22/21 [==============================] - 9s 407ms/step - loss: 0.2225 - accuracy: 0.9311 - val_loss: 0.2918 - val_accuracy: 0.8943
# Epoch 51/100
# 22/21 [==============================] - ETA: 0s - loss: 0.2352 - accuracy: 0.9168
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 3.000000106112566e-07.
# 22/21 [==============================] - 9s 414ms/step - loss: 0.2352 - accuracy: 0.9168 - val_loss: 0.3124 - val_accuracy: 0.8943
# Epoch 52/100
# 22/21 [==============================] - 9s 391ms/step - loss: 0.2220 - accuracy: 0.9240 - val_loss: 0.3059 - val_accuracy: 0.8943
# Epoch 53/100
# 22/21 [==============================] - 9s 399ms/step - loss: 0.2127 - accuracy: 0.9354 - val_loss: 0.3372 - val_accuracy: 0.8943
# Epoch 54/100
# 22/21 [==============================] - 8s 384ms/step - loss: 0.2128 - accuracy: 0.9340 - val_loss: 0.3302 - val_accuracy: 0.8943
# Epoch 55/100
# 22/21 [==============================] - 8s 384ms/step - loss: 0.2225 - accuracy: 0.9268 - val_loss: 0.3046 - val_accuracy: 0.8943
# Epoch 56/100
# 22/21 [==============================] - 9s 389ms/step - loss: 0.2004 - accuracy: 0.9412 - val_loss: 0.2829 - val_accuracy: 0.9024
# Epoch 57/100
# 22/21 [==============================] - 10s 445ms/step - loss: 0.2221 - accuracy: 0.9197 - val_loss: 0.2620 - val_accuracy: 0.9024
# Epoch 58/100
# 22/21 [==============================] - 9s 403ms/step - loss: 0.2209 - accuracy: 0.9268 - val_loss: 0.2628 - val_accuracy: 0.9024
# Epoch 59/100
# 22/21 [==============================] - 9s 392ms/step - loss: 0.2138 - accuracy: 0.9354 - val_loss: 0.2663 - val_accuracy: 0.9024
# Epoch 60/100
# 22/21 [==============================] - 9s 400ms/step - loss: 0.2156 - accuracy: 0.9326 - val_loss: 0.3078 - val_accuracy: 0.9024
# Epoch 61/100
# 22/21 [==============================] - 8s 376ms/step - loss: 0.2142 - accuracy: 0.9211 - val_loss: 0.2740 - val_accuracy: 0.8943
# Epoch 62/100
# 22/21 [==============================] - 9s 392ms/step - loss: 0.2151 - accuracy: 0.9254 - val_loss: 0.3313 - val_accuracy: 0.9024
# Epoch 63/100
# 22/21 [==============================] - 9s 408ms/step - loss: 0.2121 - accuracy: 0.9340 - val_loss: 0.3448 - val_accuracy: 0.8943
# Epoch 64/100
# 22/21 [==============================] - 9s 400ms/step - loss: 0.2414 - accuracy: 0.9168 - val_loss: 0.2771 - val_accuracy: 0.9024
# Epoch 65/100
# 22/21 [==============================] - 9s 396ms/step - loss: 0.2236 - accuracy: 0.9240 - val_loss: 0.3560 - val_accuracy: 0.9024
# Epoch 66/100
# 22/21 [==============================] - 8s 384ms/step - loss: 0.2205 - accuracy: 0.9211 - val_loss: 0.3778 - val_accuracy: 0.9024
# Epoch 67/100
# 22/21 [==============================] - ETA: 0s - loss: 0.2089 - accuracy: 0.9225
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 3.000000106112566e-08.
# 22/21 [==============================] - 8s 376ms/step - loss: 0.2089 - accuracy: 0.9225 - val_loss: 0.2711 - val_accuracy: 0.8943
# Epoch 68/100
# 22/21 [==============================] - 8s 378ms/step - loss: 0.2174 - accuracy: 0.9268 - val_loss: 0.3104 - val_accuracy: 0.9024
# Epoch 69/100
# 22/21 [==============================] - 9s 388ms/step - loss: 0.2353 - accuracy: 0.9125 - val_loss: 0.2708 - val_accuracy: 0.9024
# Epoch 70/100
# 22/21 [==============================] - 9s 415ms/step - loss: 0.2182 - accuracy: 0.9254 - val_loss: 0.2852 - val_accuracy: 0.8943
# Epoch 71/100
# 22/21 [==============================] - 9s 387ms/step - loss: 0.2141 - accuracy: 0.9240 - val_loss: 0.2874 - val_accuracy: 0.8943
# Epoch 72/100
# 22/21 [==============================] - 9s 388ms/step - loss: 0.1975 - accuracy: 0.9412 - val_loss: 0.2986 - val_accuracy: 0.8943
# Epoch 73/100
# 22/21 [==============================] - 8s 378ms/step - loss: 0.2227 - accuracy: 0.9197 - val_loss: 0.3119 - val_accuracy: 0.8943
# Epoch 74/100
# 22/21 [==============================] - 9s 387ms/step - loss: 0.2129 - accuracy: 0.9354 - val_loss: 0.2865 - val_accuracy: 0.9024
# Epoch 75/100
# 22/21 [==============================] - 9s 394ms/step - loss: 0.2161 - accuracy: 0.9211 - val_loss: 0.2638 - val_accuracy: 0.9024
# Epoch 76/100
# 22/21 [==============================] - 9s 391ms/step - loss: 0.2151 - accuracy: 0.9354 - val_loss: 0.2735 - val_accuracy: 0.8943
# Epoch 77/100
# 22/21 [==============================] - ETA: 0s - loss: 0.2176 - accuracy: 0.9240Restoring model weights from the end of the best epoch.
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 3.000000248221113e-09.
# 22/21 [==============================] - 9s 403ms/step - loss: 0.2176 - accuracy: 0.9240 - val_loss: 0.2741 - val_accuracy: 0.8943
# Epoch 00077: early stopping

# %%
model.evaluate(test_imgs, test_df)
# Out:
# 7/7 [==============================] - 0s 51ms/step - loss: 0.2190 - accuracy: 0.9320
# [0.21904848515987396, 0.9320388436317444]
